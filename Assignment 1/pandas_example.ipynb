# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv('./datasets/life-expectancy.csv', sep=',')
df = pd.read_csv('https://gist.githubusercontent.com/foolnotion/bd288197566091d290647b74065d4b0e/raw/66211840b07d40619601cb96c79948d002342b9b/life-expectancy.csv')
df
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy  Adult Mortality  infant deaths  \
# count  2938.000000      2928.000000      2928.000000    2938.000000
# mean   2007.518720        69.224932       164.796448      30.303948
# std       4.613841         9.523867       124.292079     117.926501
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        63.100000        74.000000       0.000000
# 50%    2008.000000        72.100000       144.000000       3.000000
# 75%    2012.000000        75.700000       228.000000      22.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %% [markdown]
# How about seeing highest life expectancy countries?

# %%
df_sorted = df.sort_values(['Life expectancy', 'Alcohol', 'BMI'], ascending=False)
df_sorted.head(20)
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 241       Belgium  2014   Developed             89.0             76.0
# 938        France  2007  Developing             89.0             89.0
# 937        France  2008  Developing             89.0             88.0
# 2433        Spain  2007   Developed             89.0             72.0
# 995       Germany  2014   Developed             89.0             69.0
# 2056     Portugal  2014   Developed             89.0             78.0
# 1850  New Zealand  2010   Developed             89.0             71.0
# 1293        Italy  2004   Developed             89.0             66.0
# 915       Finland  2014  Developing             89.0             78.0
# 2513       Sweden  2007   Developed             89.0             63.0
# 1916       Norway  2009   Developed             89.0             67.0
# 131       Austria  2012   Developed             88.0              7.0
# ...

# %%
df = df.select_dtypes(include=np.number)
df = df.dropna(how='any')
df
# Out:
#       Year  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0     2015             65.0            263.0             62     0.01
# 1     2014             59.9            271.0             64     0.01
# 2     2013             59.9            268.0             66     0.01
# 3     2012             59.5            272.0             69     0.01
# 4     2011             59.2            275.0             71     0.01
# ...    ...              ...              ...            ...      ...
# 2933  2004             44.3            723.0             27     4.36
# 2934  2003             44.5            715.0             26     4.06
# 2935  2002             44.8             73.0             25     4.43
# 2936  2001             45.3            686.0             25     1.72
# 2937  2000             46.0            665.0             24     1.68
#
#       percentage expenditure  Hepatitis B  Measles   BMI  under-five deaths  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig, ax = plt.subplots()
ax.hist(df['Adult Mortality'])
# Out:
# (array([389., 409., 388., 258.,  73.,  65.,  30.,  15.,  10.,  12.]),
#  array([  1. ,  73.2, 145.4, 217.6, 289.8, 362. , 434.2, 506.4, 578.6,
#         650.8, 723. ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

X_train, X_test, y_train, y_test = train_test_split(df[df.columns[:-1]], df[df.columns[-1]])

lr = LinearRegression()
lr.fit(X_train, y_train)

y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)

r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

r2_train, r2_test
# Out:
# (0.7501730854446983, 0.756419264077778)
